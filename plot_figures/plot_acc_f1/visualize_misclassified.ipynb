# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

xticks = [f'DS_{i}' for i in range(1, 21)]

# %% [markdown]
# ### Plot misclassified sequence numbers of Tiara and Whokaryote

# %%
tiara = pd.read_csv('/home/tianqi/project/DeepMicrobeFinder/perf_summary/misclassified_tiara.csv')
tiara.index = xticks

whokaryote = pd.read_csv('/home/tianqi/project/DeepMicrobeFinder/perf_summary/misclassified_whokaryote.csv')
whokaryote.index = xticks

fig, ax = plt.subplots(1, 2, figsize=(12, 5))
tiara.plot.bar(stacked=True, ax=ax[0])
ax[0].set_title('Tiara')
ax[0].set_ylabel('Number of misclassified samples')
ax[0].set_ylim(0, 100)
ax[0].tick_params(axis='x', labelrotation=30)


whokaryote.plot.bar(stacked=True, ax=ax[1])
ax[1].set_title('Whokaryote')
ax[1].set_ylim(0, 500)
ax[1].tick_params(axis='x', labelrotation=30)

fig.tight_layout()
fig.supxlabel('Dataset')
fig.savefig('/home/tianqi/project/DeepMicrobeFinder/plot_figures/plot_acc_f1/analysis_results/mistake_euk.pdf', bbox_inches='tight')

# %% [markdown]
# ### Plot misclassfied plasmid sequence numbers of Plasflow and PPR-Meta

# %%
plasflow = pd.read_csv('/home/tianqi/project/DeepMicrobeFinder/perf_summary/misclassified_plasflow.csv')
plasflow.index = xticks

ppr = pd.read_csv('/home/tianqi/project/DeepMicrobeFinder/perf_summary/misclassified_ppr.csv')
ppr.index = xticks

fig, ax = plt.subplots(1, 2, figsize=(12, 5))
plasflow.plot.bar(stacked=True, ax=ax[0])
ax[0].set_title('PlasFlow')
ax[0].set_ylabel('Number of misclassified samples')
ax[0].set_ylim(0, 400)
ax[0].tick_params(axis='x', labelrotation=30)

ppr.plot.bar(stacked=True, ax=ax[1])
ax[1].set_title('PPR-Meta')
ax[1].set_ylim(0, 400)
ax[1].tick_params(axis='x', labelrotation=30)

fig.tight_layout()
fig.supxlabel('Dataset')
fig.savefig('/home/tianqi/project/DeepMicrobeFinder/plot_figures/plot_acc_f1/analysis_results/mistake_plas.pdf', bbox_inches='tight')

# %% [markdown]
# ### Plot misclassified sequence numbers of DeepMicroClass

# %%
dmc = pd.read_csv('/home/tianqi/project/DeepMicrobeFinder/perf_summary/misclassified_dmc.csv')
dmc.index = xticks

fig, ax = plt.subplots(1, 1, figsize=(6, 5))
dmc.plot.bar(stacked=True, ax=ax)
ax.set_title('DeepMicroClass')
ax.set_ylabel('Number of misclassified samples')
ax.set_ylim(0, 50)
ax.set_xlabel('Dataset')
ax.tick_params(axis='x', labelrotation=30)
# make legend smalle
ax.legend(prop={'size': 6})

fig.tight_layout()
fig.savefig('/home/tianqi/project/DeepMicrobeFinder/plot_figures/plot_acc_f1/analysis_results/mistake_dmc.pdf', bbox_inches='tight')

# %% [markdown]
# ### Plot misclassified virus sequence numbers of DVF, PPR and VIBRANT

# %%
ppr = pd.read_csv('/home/tianqi/project/DeepMicrobeFinder/perf_summary/misclassified_ppr_prokvir.csv')
ppr.index = xticks

dvf = pd.read_csv('/home/tianqi/project/DeepMicrobeFinder/perf_summary/misclassified_dvf.csv')
dvf.index = xticks

vibrant = pd.read_csv('/home/tianqi/project/DeepMicrobeFinder/perf_summary/misclassified_vibrant.csv')
vibrant.index = xticks

virsorter = pd.read_csv('/home/tianqi/project/DeepMicrobeFinder/perf_summary/misclassified_virsorter2.csv')
virsorter.index = xticks

fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ppr.plot.bar(stacked=True, ax=ax[0, 0])
ax[0, 0].set_title('PPR-Meta')
ax[0, 0].set_ylabel('Number of misclassified samples')
ax[0, 0].set_ylim(0, 500)
ax[0, 0].tick_params(axis='x', labelrotation=30)

dvf.plot.bar(stacked=True, ax=ax[0, 1])
ax[0, 1].set_title('DeepVirFinder')
ax[0, 1].set_ylim(0, 500)
ax[0, 1].tick_params(axis='x', labelrotation=30)

vibrant.plot.bar(stacked=True, ax=ax[1, 0])
ax[1, 0].set_title('VIBRANT')
ax[1, 0].set_ylabel('Number of misclassified samples')
ax[1, 0].set_ylim(0, 50)
ax[1, 0].tick_params(axis='x', labelrotation=30)

virsorter.plot.bar(stacked=True, ax=ax[1, 1])
ax[1, 1].set_title('VirSorter2')
ax[1, 1].set_ylim(0, 80)
ax[1, 1].tick_params(axis='x', labelrotation=30)

fig.tight_layout()
fig.supxlabel('Dataset')
fig.savefig('/home/tianqi/project/DeepMicrobeFinder/plot_figures/plot_acc_f1/analysis_results/mistake_vir.pdf', bbox_inches='tight')
